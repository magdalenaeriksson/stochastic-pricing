# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join("..")))
from src.simulation import simulate_gbm

# %%
import matplotlib.pyplot as plt

t, S = simulate_gbm(n_paths=3)
plt.plot(t, S)
plt.show()
